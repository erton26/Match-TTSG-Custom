# %% [markdown]
# # Match-TTSG: UNIFIED SPEECH AND GESTURE SYNTHESIS USING FLOW MATCHING
# ---
# [Shivam Mehta](https://www.kth.se/profile/smehta), [Ruibo Tu](https://www.kth.se/profile/ruibo), [Simon Alexanderson
# ](https://www.kth.se/profile/simonal?l=en) [Jonas Beskow](https://www.kth.se/profile/beskow), [Éva Székely](https://www.kth.se/profile/szekely), and [Gustav Eje Henter](https://people.kth.se/~ghe/)
#
# As text-to-speech technologies achieve remarkable naturalness in read-aloud tasks, there is growing interest in multimodal synthesis of verbal and non-verbal communicative behaviour, such as spontaneous speech and associated body gestures. This paper presents a novel, unified architecture for jointly synthesising speech acoustics and skeleton-based 3D gesture motion from text, trained using optimal-transport conditional flow matching (OT-CFM). The proposed architecture is simpler than the previous state of the art, has a smaller memory footprint, and can capture the joint distribution of speech and gestures, generating both modalities together in one single process. The new training regime, meanwhile, enables better synthesis quality in much fewer steps (network evaluations) than before. Uni- and multimodal subjective tests demonstrate improved speech naturalness, gesture human-likeness, and cross-modal appropriateness compared to existing benchmarks.
#
# Demo Page: https://shivammehta25.github.io/Match-TTSG \
# Code: https://github.com/shivammehta25/Match-TTSG

# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
import datetime as dt
import warnings
from pathlib import Path

import ffmpeg
import IPython.display as ipd
import joblib as jl
import numpy as np
import soundfile as sf
import torch
from tqdm.auto import tqdm

# Hifigan imports
from match_ttsg.hifigan.config import v1
from match_ttsg.hifigan.denoiser import Denoiser
from match_ttsg.hifigan.env import AttrDict
from match_ttsg.hifigan.models import Generator as HiFiGAN
# MatchTTSG imports
from match_ttsg.models.match_ttsg_custom_deca import MatchTTSGCustomDECA
from match_ttsg.text import sequence_to_text, text_to_sequence
from match_ttsg.utils.model import denormalize
from match_ttsg.utils.utils import get_user_data_dir, intersperse

# Motion visualisation imports
from pymo.preprocessing import MocapParameterizer
from pymo.viz_tools import render_mp4
from pymo.writers import BVHWriter

import speechbrain
from speechbrain.inference.vocoders import HIFIGAN
import pandas as pd
import pickle

# %%
print(speechbrain.__version__)
print(torch.__version__)
# Out:
# 1.0.2

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# This allows for real time code changes being reflected in the notebook, no need to restart the kernel
# Out:
# /home/ayrton/anaconda3/envs/match-ttsg-wsl/lib/python3.10/site-packages/IPython/extensions/autoreload.py:211: UserWarning: Module 'speechbrain.pretrained' was deprecated, redirecting to 'speechbrain.inference'. Please update your script. This is a change from SpeechBrain 1.0. See: https://github.com/speechbrain/speechbrain/releases/tag/v1.0.0
#   if not hasattr(module, "__file__") or module.__file__ is None:

# %%
print(torch.cuda.is_available())
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# True

# %%
import torchaudio
print(torchaudio.__version__)
# Out:
# 2.5.1+cu124

# %% [markdown]
# ## Filepaths

# %%
MATCHTTSGDECA_CHECKPOINT = "/home/git/Match-TTSG/logs/train/multimodal_base_verbatim_baseline/runs/2025-09-11_14-47-30/checkpoints/last.ckpt"
#MOTION_PIPELINE = "match_ttsg/resources/data_pipe.expmap_86.1328125fps.sav"
HIFIGAN_CHECKPOINT = get_user_data_dir() / "generator_v1"#"hifigan_T2_v1"
OUTPUT_FOLDER = "synth_output"

print(HIFIGAN_CHECKPOINT)
# Out:
# /home/ayrton/.local/share/matcha_tts/generator_v1

# %% [markdown]
# ## Load Match-TTSG

# %%
def load_model(checkpoint_path):
    model = MatchTTSGCustomDECA.load_from_checkpoint(checkpoint_path, map_location=device)
    model.eval()
    return model
count_params = lambda x: f"{sum(p.numel() for p in x.parameters()):,}"


model = load_model(MATCHTTSGDECA_CHECKPOINT)
print(f"Model loaded! Parameter count: {count_params(model)}")
# Out:
# Model loaded! Parameter count: 18,453,009

# %% [markdown]
# ## Load HiFi-GAN (Vocoder)

# %%
def load_vocoder(checkpoint_path):
    h = AttrDict(v1)
    hifigan = HiFiGAN(h).to(device)
    hifigan.load_state_dict(torch.load(checkpoint_path, map_location=device)['generator'])
    _ = hifigan.eval()
    hifigan.remove_weight_norm()
    return hifigan

vocoder = load_vocoder(HIFIGAN_CHECKPOINT)
#denoiser = Denoiser(vocoder, mode='zeros')
# Out:
# /home/ayrton/anaconda3/envs/match-ttsg-wsl/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# /tmp/ipykernel_10162/984558455.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   hifigan.load_state_dict(torch.load(checkpoint_path, map_location=device)['generator'])
# Removing weight norm...

# %% [markdown]
# # Load motion visualiser

# %%
## Number of ODE Solver steps
n_timesteps = 500

## Changes to the speaking rate
length_scale=1.0

## Sampling temperature
temperature = 0.667

# %% [markdown]
# ### Helper functions to synthesise

# %%
@torch.inference_mode()
def process_text(text: str):
    #x = torch.tensor(intersperse(text_to_sequence(text, ['japanese_accent_cleaners']), 0),dtype=torch.long, device=device)[None]
    x = torch.tensor(text_to_sequence(text, ['japanese_accent_cleaners']),dtype=torch.long, device=device)[None]
    x_lengths = torch.tensor([x.shape[-1]],dtype=torch.long, device=device)
    x_phones = sequence_to_text(x.squeeze(0).tolist())
    return {
        'x_orig': text,
        'x': x,
        'x_lengths': x_lengths,
        'x_phones': x_phones
    }


@torch.inference_mode()
def synthesise(text, spks=None):
    text_processed = process_text(text)
    start_t = dt.datetime.now()
    output = model.synthesise(
        text_processed['x'], 
        text_processed['x_lengths'],
        n_timesteps=n_timesteps,
        temperature=temperature,
        spks=spks,
        length_scale=length_scale
    )
    # merge everything to one dict    
    output.update({'start_t': start_t, **text_processed})
    return output

@torch.inference_mode()
def to_waveform(mel, vocoder):
    hifi_gan = HIFIGAN.from_hparams(source="speechbrain/tts-hifigan-libritts-16kHz", savedir="pretrained_models/tts-hifigan-libritts-16kHz")
    audio = hifi_gan.decode_batch(mel)
    return audio.cpu().squeeze()

"""
def to_waveform(mel, vocoder):
    audio = vocoder(mel).clamp(-1, 1)
    audio = denoiser(audio.squeeze(0), strength=0.00025).cpu().squeeze()
    return audio.cpu().squeeze()
"""

"""
def to_bvh(motion):
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        return motion_pipeline.inverse_transform([motion.cpu().squeeze(0).T])
"""  
def save_to_folder(filename: str, output: dict, folder: str):
    folder = Path(folder)
    folder.mkdir(exist_ok=True, parents=True)
    np.save(folder / f'{filename}', output['mel'].cpu().numpy())
    sf.write(folder / f'{filename}.wav', output['waveform'], 16000, 'PCM_24')
    #with open(folder / f'{filename}.bvh', 'w') as f:
        #bvh_writer.write(output['bvh'], f)

def save_to_movement_csv(filename: str, output: dict, folder:str):
    folder = Path(folder)
    folder.mkdir(exist_ok=True, parents=True)
    expression_df = pd.DataFrame(output['expression'].cpu().squeeze().T.numpy())
    pose_df = pd.DataFrame(output['pose'].cpu().squeeze().T.numpy())
    with open(f"./{folder}/{filename}.decaexp.pkl", 'wb') as f:
        pickle.dump(expression_df, f)
    with open(f"./{folder}/{filename}.decapose.pkl", 'wb') as f:
        pickle.dump(pose_df, f)
    
"""
def to_stick_video(filename, bvh, folder):
    folder = Path(folder)
    folder.mkdir(exist_ok=True, parents=True)

    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        X_pos = mocap_params.fit_transform([bvh])
    print(f"rendering {filename} ...")
    render_mp4(X_pos[0], folder / f'{filename}.mp4', axis_scale=200)


def combine_audio_video(filename: str, folder: str):
    print("Combining audio and video")
    folder = Path(folder)
    folder.mkdir(exist_ok=True, parents=True)

    input_video = ffmpeg.input(str(folder / f'{filename}.mp4'))
    input_audio = ffmpeg.input(str(folder / f'{filename}.wav'))
    output_filename = folder / f'{filename}_audio.mp4'
    ffmpeg.concat(input_video, input_audio, v=1, a=1).output(str(output_filename)).run(overwrite_output=True)
    print(f"Final output with audio: {output_filename}")
"""
# Out:
# '\ndef to_stick_video(filename, bvh, folder):\n    folder = Path(folder)\n    folder.mkdir(exist_ok=True, parents=True)\n\n    with warnings.catch_warnings():\n        warnings.simplefilter("ignore")\n        X_pos = mocap_params.fit_transform([bvh])\n    print(f"rendering {filename} ...")\n    render_mp4(X_pos[0], folder / f\'{filename}.mp4\', axis_scale=200)\n\n\ndef combine_audio_video(filename: str, folder: str):\n    print("Combining audio and video")\n    folder = Path(folder)\n    folder.mkdir(exist_ok=True, parents=True)\n\n    input_video = ffmpeg.input(str(folder / f\'{filename}.mp4\'))\n    input_audio = ffmpeg.input(str(folder / f\'{filename}.wav\'))\n    output_filename = folder / f\'{filename}_audio.mp4\'\n    ffmpeg.concat(input_video, input_audio, v=1, a=1).output(str(output_filename)).run(overwrite_output=True)\n    print(f"Final output with audio: {output_filename}")\n'

# %% [markdown]
# ## Setup text to synthesise

# %%
test_data_text_list = []
test_data_text_path = "../data/multimodal_single_kon_verbatim_DECA/test.txt"
with open(test_data_text_path, 'r') as f:
    for line in f:
        text = line.strip().split("|")[1]
        print(text)
        test_data_text_list.append(text)
# Out:
# 水泳とか、機械体操とか、そういうのは、まあ、短距離とかは、まあ、できるんですけど、もう、物を使うってなったと、途端に、もう。
# 当てて、しかも追っかけてって、また当てて追っかけてってって、あれ、なんか、
# 見る専門でお願いしますって感じですね。そこ、あの、応援しますみたいな感じですね。
# さ、じゃあ、えっと、今日のテーマはスポーツについてですが、
# うーん、なんかもう、ちょっと、その、応援するっていうか、まあ、確かに、ド、まあ、ドラマがあるので、それを、ドラマを、人間ドラマを見るみたいな感じで観戦はしたりはしますけど。
# ねー、ちょっと。
# 気持ち、楽しいって言ったらやっぱり対戦の方が、できなくても楽しいのは対戦の方かなと思いますよね。
# そういうものだったんだ。
# よくわかんないです。なんか、私の中では、あの、鉄線とかのイメージ。えへへ。なぜ、なんでそんな鉄線とか貼っちゃうのかなーみたいな。刺さるし。
# 美しい人とかいるじゃないですか、なんか。いますよね、その、戦いが美しい人が。
# 特にね、夏はビールを片手にね、観戦するっていうのが最高です。
# あれですかね、フットサルってあの、サッカーよりもコートが狭いんでしたっけ?
# 体育館の半分ぐらいな感じの。
# うん。
# そこか。そういう理由。
# 今も、え、なに、何県ですか?
# よろしくお願いします。えーと、今回のテーマは動物ということなんですが、どうですか?あの、動物はお好きな方ですか?
# すっごい失踪してた記憶があります。公園とかを。
# そっか、長毛はだから、か、長毛はだから、こう、ただつくじゃなく、からまるー。
# そんな子がいるんですか?毛が抜けない品種の。抜けづらい。
# くしゃくしゃしてる。くしゃくしゃした系。
# なんか、やっぱり、犬は、あれですよね、結構品種改良がしっかりしてるっていう感じですよね。
# でも、なんか、猫は、その、飼いやすさとか、働き方とかじゃなく、ただただ可愛さを追求した変種改良ですよね。
# しっぽで、あの、ブラッシングすると、すごい嫌がられました。
# わかります。毛、毛がね、生えてないの、ちょっとね、はっ、ちょっと、エキゾチックなやつとか。
# あれ、なんなんだろうと思って、絶対間に入る。
# ちょっとしたくぼみが、こう、心地いいんだと思うんですけど、脇の下とかね。
# 犬だと、あ、でも、犬って、もう、寝るときは寝室とかにベッド置いたりとかして、一緒に寝る感じなんですよね。
# 結構、嫌いってことですね。逃げちゃう。
# それ正解ですよ。もう、ほんとそれ正解。
# もう、なんか、芝生だ、は、もう、ほんと、それ、それ、全面ですよ、もう、ほんと。全面、芝生に、雑草生え放題、みたいな。
# 虫もいっぱい出ますしね、ほっとくと。
# 鉢植えとかに植わってる花の葉っぱとかまで、こう、食われる。そう、もう、なめくじにも食われる、みたいな感じで、もう、大変、大変です。あ、でも、あの、発作が終わってるので、それだけはちょっと、
# 楽しんでください。私も追いかけます。マイホーム。
# 厳しい。
# ってことは、お腹大きい時は、まだ、3階建てに住んで、
# それだったらいいのかもしれないですね。その、エアコンつけて、サイキュレーターつけて、かき混ぜたら、たぶん、大丈夫かも。あんまりそっ、やったことがなかったかもしれないですね。
# よろしくお願いします。
# 一人暮らししてた時なんかは、あれでしたよ、私でも、冬は、いつも布団とか毛布とか、家の中で、そう、家の中でなんか、コート着たりとかしてましたけどね、やっぱ家族ができるとね、そうも言ってられないって感じですよね。
# え、ダメなんですよね、あの、歳とってからそういうのって、ヒートショックでしたっけ、なんか。
# うちも、あれですよ、だ、暖房器具置いてます。洗面所に、うん、あのー、すぐ暖かくなる、あの、電気ヒーターみたいなのあるじゃないですか。ほ、ほ、細いやつ。あれを置いて、もう、上がったらすぐつけて、その前で着替えるっていう感じで、やってますね。
# 失礼します。
# どっちかと言えば寒い方は、あの、結構、着込めば大丈夫っていう感じで、まあ、冬生まれなので、っていうか、言うって関係あるのかわかんないですけど。
# 寒いのが嫌だっていうか、もう、もう、大変だからっていうか。
# こんにちは。
# ぜいぶん移動しましたね。
# 長い。
# うーん、2拍以上は確かにしたいのはわかります。
# 緊張したりしないんですか?その、大丈夫かな?とか、迷子にならないかな?とか、不安にならないですか?その、計画せずに、よっしゃ!みたいに言った先で。
# すごい。
# めっちゃポジティブ。
# 確かに予定しておくと、なんか、イメトレしちゃってるし、あの、観光の雑誌とかも見、景色とかも見ちゃってから、そこに行こうとしてるから、まあ、ある意味、ちょっと感動は半減してますもんね、予定してたら。
# そうですよね、あのー、ね、雑誌とかネットとかの、いわゆるその、業者が出してる有名観光地ってほんと限られてて、あの、インスタのいわゆる一般のその地元の人とかが、ここっていう写真とか載せてるの、ほんと、すごいいっぱいありますよね。もう、そんな絶景の場所がまだあるのかみたいに、確かに思いますね。
# もう、旅行のプロですね。
# いいですね、その、やっぱり、しゃべったりとかしないと、ちょっと、あれですもんね、あの、行っても、孤独というか、ただ見て回ってるっていうだけになったりとかするから、やっぱり、お店とかでしゃべったりするの、大事ですよね、その、と、その土地に、今、私、いますって感じますよね、その、土地の人としゃべったりとかすると。
# そこで聞いて行ったりとかするんですか?
# 最近、ネットとかばっかりで、その、バーチャルでしか人とつながりがなくなってきてますけど、やっぱり実際に行って、人の関係を広げるっていいんだと思ったところで、お時間が来てしまったようです。
# 最近、
# おいしいですよね。
# やっぱり、あれですか、泊りがけで行くときは、あのー、旅館系を選ぶ感じですか、ホテル系ではなく。
# そうなんですね。え、今回、その、直近で言ったのは、えっと、お友達と行ったりとかしたってことですか?
# こんにちは。
# そうそう。え、これ自分で見てすごい気持ち悪いと思って、もう、ピタッとやめました。
# ね、自分でもちょっと、やばいなと思いました。
# 陸上で多分走ったりしてると、暑いとずっと暑いじゃないですか。
# そう、で、汗とかもか、かくじゃないですか。
# 何日かけてとか思うんですけど、一日で。
# そりゃ、そうですよね。人生40何キロも走ることないですもん。新しい扉が開きますよね、そりゃ。
# はい、ということで、そろそろお時間がよろしいようです。
# 全然、毛色が違いますよね。柔道とフットサル。
# そうですね、なんか、暇だったっていうのもあって、あの、結婚して、仕事を辞めて、しばらくした後だったので、もう、時間が有り余ってて、暇すぎて、1日7キロぐらい毎日泳いでました。
# そうそう、なんか、基本、その、ファンタジーに見せかけて、基本、なんか、主人公転生してて、さらに、その、主人公だけ転生してるのかと思いきや、なんか、最後の方で、その、相手方も転生してましたとかいう暴露があったり。
# そう、して、どんだけ訂正してんだよ、っていう。
# 長い。
# それ、結構、でも、課金して、次の、その、回が、薄かったりすると、ショック大きかったりしますよね。
# なんだったんだ、ここまでの、みたいな。
# そう、隅々まで。
# そう、ね、なんか、前はね、こう、紙で読むと、パラパラパラって言って終わっちゃったりとか、スルーしてたところとかも、もう、ほんと、つぶさにチェックしますよね。
# そうそう、え、どうなっちゃうの、つらいって、いう時は、そう、その人たちの、いろんな人たちの、励ましを持って、プロローグ戻って、そっか、ここ、きっと最終的にはこのプロローグのこの辺にたどり着けるっていうことだよね、これ伏線だよね、とか、思いながら、読み進めたりしますね。
# ね、紙とまた全然、紙もね、いいですけどね、手元にあるっていうのもいいんですけど、やっぱり、人と話しながら、その、コメントとかで、コミュニケーション取りながら、読むと、楽しいですね。ということで、えー、お時間がよろしいようです。
# そうそう。そういうので、つい。
# はれ、流行りだしたのって、あれですかね、スライム、スライムに訂正したあたりからですかね。なんかありましたよね、流行ったやつ。
# ね、最近、だから、なんか、転生してないやつを探すのが大変っていう感じで。
# ピザ、そうか、そうか。えっ、もしかしてピザ、ピザも作っちゃったりとかします?
# よかった。これで作るとか言われたら、もう、なんか、私、この料理に話をしたの間違ったなと思って、後悔し始めてた。
# そんなことないですよ。
# 探究心が。
# そういうのって、え、そういうコツとかって、どっからこう、入手してるんですか?
# はい。スーパー主婦になってください。
# はい、ありがとうございました。
# うーん。
# 一応、日本海側になるのかな、あのー、東シナ海って言えばいいのかな、あのー、海があるので、一応、寒いことは寒いんですけど、でも、それで、言っても、東北とかに比べて、その、外気がマイナスになることってほとんどないので、なのに、家の中は10度みたいな、あ、0度みたいなことが起きるんですよ。
# そうかもしれないですね。そうかも。あんまりその、だから、寒さ対策がされてないので、もう。
# そうなんですよ、やばい、冬、あのー、朝とか、ひーって感じですよ。
# そうかもしれない。もう、だから、暖房代とか、多分、すごいかかってると思います。
# いい加減にしろって感じですね。そんな続くと。うち、長くても半日ぐらいで済むので我慢できますけど。
# それは、あのー、寝てるときに、あれですね、油断してると、あるひとつで、すごい音で、
# すごい、へ、山が近いってことなんですかね。山がある。
# すごい、なんか、ちょっと、日本の原風景になってる感じ。
# 同感です。そうですね。あのー、言動器っていうのかな?あのー、発動器っていうんですかね。あれが激うるさいんですよね。
# そうですよね。若干、多分、メーカーが手抜いてるっていうか、その、そーまで、コストかけてやらないんですよ、きっと。
# そうかも、ちょっと。
# はーい、じゃあ、そろそろお時間がよろしいようなので、この辺で失礼したいと思います。
# はい、ありがとうございました。
# じゃあ、むしろ逆にその、家としてはすごいこう、防寒対策されてるような感じなんですか?
# そうなんですよ。むしろ、なんか、冷蔵庫開けても、全然、冷蔵庫の中の方が、なんか、そんなに、あったかいぐらいな感じの。
# 気持ち重要ですよね。食事をしながら、洗いが待ってると思うと、ちょっと食事がね。
# あれですよね、感想までしてくれるんですよね。
# 工事がないってことは、持ち運べるっていうことだから、引っ越しもOKなんですよね。
# ちなみに、おいくらぐらいだったんですか?とか聞いちゃおうかな。
# 行こうかなと思わせますよね。
# 工事代がなくて。
# 買うとき、その、旦那さんとかと、その、旦那さんも、もう、イケイケGO!って感じだったんですか?
# 普段、洗ってくれない、普段洗ってくれない人だと、そのぐらい、買わずに手でやんなよとか、逆に言いそう、やらない人に限って。
# 今日は、家事についてお話ししていこうかなと思うんですけど、どうですか?家事は基本的にいろいろ、
# もともと旦那さんは、その、食器洗いの、その、まあ、バトルするにしても、やってくれる方なんですか?食器洗い以外の家事とかも。
# めんどくさい時は、ああ、今日は、パパの、パパの焼きそばの気分かな、みたいな。
# 今日はありがとうございました。
# お皿洗い、嫌いって、あれですかね、あの、私と、私は結構、お皿洗いは、好きな方で、あのー、冬とか、お湯使って洗うと、ちょっとこう、ほっこりするというか、温まるー、とか思いのぐらいやったりするので、あんまり、嫌いな方ではないんですけど、あれですかね、食べ終わった後に、立ち上がるのが面倒になる系ですか。
# あれですか、じゃあ、あのー、食洗機とか導入は?
# どのぐらいだった? 遠いっていうのは、1時間とか、そんな感じ。
# よろしくお願いします。
# はい、では失礼します。
# それ、じゃあ、買い替えるよって思っちゃいますね。
# あれですよね、もう、一括0円的な、その、大幅値引きみたいなのって、法律でもう禁止されるようになっちゃったんですよね、確か。
# ちょっと、意図がわからないですよね、意図が。
# 私は逆ですよ。白ロムを買って使ってた方です。
# やっぱスマホ中古はいかんなと思って、速攻返却しました。これ使い物になりません。そう、で、Amazonなんか結構返品はゆるいので、結構さっくり。
# CPSあったらね、すごい安心ですもんね。そういう時もね。どこにいるって。
# 早いですね。
# でも結果的に、だから、1年、2年間で2万円ぐらいで済むみたいな感じですよね。
# あ、んふふふ。
# 毎日だよー、みたいな。
# じゃあ、うち、受けてみれば?
# いい、いいです。
# あははははははは。
# アルバイトについてなんですけど、どうですか?アルバイトは結構経験はされたことはありますか?
# あーーー。
# 話をし。
# え、どうですか?友達できました?うん、おおー、おおー、すごいですね。一生ものの友達ができました。
# それ、結構、興味ありますね。
# どうですか?ない、特にないですか?
# ネズミさんってやつだ。
# 相当、相当、衝撃を、心に、なんか、感じてしまったんですね。確かに、でも、想像すると、ちょっと気持ち悪い。
# えーと、今回は、動物について、お話をしていこうかなと思うんですけど、動物、動物、動物園って、そう、動物園って行かれたことあります?
# 買うとしたら、雑種ですかね。それとも、血統書付きの。
# じゃあ、野望が、猫の野望が、早く叶う日を祈りつつ、お時間が、えー、来てしまったようです。はい、今日はありがとうございました。
# だから、生。
# こんにちは。
# いい案だと思います。ね、早くね、晴れて、プールが入れるといいですね。
# 排水の陣で。
# 病院とかもね、その、近くにあるかっていうと、田舎だと、あのー、選択肢も限られるし。
# よろしくお願いします。
# まさに、今、今住んでるところが、そんなところですよ。
# もうね、私もずっと東京近辺で生まれ育ったので、あのー、電車の乗り継ぎとかも、その、普通に降りたら、次の電車に普通に、もう1分、2分待てば、次の乗れるっていう感覚だったんですけど、もう、今住んでるところは、ね、乗り継ごうもんなら、乗り継ぎに30分とか。
# まさにそれですよ、うちの。
# 車がね、やっぱり、な、ないと、ちょっと、厳しいなーって、すごい、思うので、将来的に、私、ここに住むのかなって、ずーっと思ってます。
# 同居してるわけじゃないから、そのー、そこそこ距離感があって、で、あの、多分、遠距離に住んでる方よりも、ちょっと、あの、止まったことが一回もない。
# えー、まず、止まりから練習しないといけない感じ。
# どうしたらいいんでしょうね、将来設計。
# 流行りの卒婚かな?とか。
# そうなんですよー。
# ちょっと、希望的観測なんですけど。
# かもしれない。
# 頑張りましょう。
# 住むところをまず悩ましいなと思ってて、
# ちょっと、せんせん、きょうきょうとしてる感じですかね。
# えー、難しいですね。そんな、そんなことで?みたいな感じですよね。
# あ、集合住宅ってことですか?社宅の。
# マイマナーですよね、それ。
# よろしくお願いします。
# お家の中で運動してるのかな?とか。
# ごご。
# でも、そっか、そうですね、騒音もマナーの一つといえばマナーですもんね。静かに、夜は静かに過ごしましょうって。
# どうだろう?
# うち、うちの目の前がその集合住宅なんですけど、ええ、もう、はい。ちょうど目の前、お迎えの方が、ちょうどお子さん小さくて、あの、窓開けていて。
# 確かに、なかなかね、難しいかも。
# 見てみたい。
# ありがとうございました。
# よろしくお願いします。
# おじさんとかが、いる、いらっしゃるので、まあ、そういう意味では、ちょっと、まあ、ちょっと、あれな人もいますけど、それでも、
# あんまり聞かないですね。田舎だから。
# かなっていう気がしますね。夜とかも、まあ、暗いんですけど、人が本当に夜、歩いてないんですよね。
# ありますね。
# さらわれちゃうかもしれない。
# 公立が行きたくなくて私立に行くっていう理由の一つに、やっぱりそういうのありますよね。治安とか。
# 言われますね。
# そこでね、分譲の家とかに住んでたら、もう、ほんと、地獄だなと思いますね。
# こわっ。
# 怖い。
# 怖い。
# ね、最初、調べて入ったとしても、隣が引っ越してまた違う人が来る可能性もね、ありますしね。
# やっぱり、身体かな?極力、長く、できるだけ長く、身体で。
# って気がしましたけど、でも、マイホームの夢がなかなか素敵です。
# 悩ましい。
# ちょっと、そのへんのゲーム欲しいとか言ってくれた方がよっぽど。
# そうですよね。だって、入場料で1人1万とか取られた日には、ねえ、大変。すごい。
# なんか、そういうの、ディズニーランドぐらいしか、あのー、イメージがなかったですけど、USJも。
# そうなんだ。
# はーへー。
# 怖い。
# 恐ろしい。
# ありがとうございました。
# そう、気がついたら量が減ってったりとかするものも結構ありますよね。同じ値段なのに。
# ですよね。ほぼパクチー。
# カメムシ大量発生みたいな。
# ハメ虫、そういえば、そうですね。あ、でも、これから夏、夏が来て、夏が終わるぐらいに出てくるんじゃないかな。
# あ、日本酒好きなんですか?
# なる。あれですか、自宅で飲んだりもしたりします?
# 喉越しがね。
# ですね、私も。いつの間にか。もう、何だったら、ノンアルでもビールは美味しいと思っちゃうぐらい。
# いいなー。あれですか、えーと、途中で泊まるってことは、大体1泊、1泊2日でご実家に帰られて、な、全校庭で何日間ぐらい行ってらっしゃるんですか?
# あれですかね、受験が終わったら、もう、あれですか、家族で旅行っていうよりは、友達と行きたいんだよって言われちゃう感じなんですかね。
# お願いします。
# 甥っ子とか、女っ子とかの周り見てると、あんまりその、自分がその年代だった頃のように、親とは衝突せずに、いつまでも仲良しな雰囲気を、こう、かもしてますけど。だから大丈夫と思って。
# 中3でそれだったら、もう、なんか、全然、余裕で、反抗期なしで、終わりそうな、気がしますけど。
# いいなー。韓国の料理も美味しいし、イタリアって言ったらやっぱり、ピザ?パスタ?
# 休みたい、みたいな。
# そうですね、東の方から西の端の方まで行ってるって感じ。はい、いいですね。
# といー。
# なんか、できない自分がおかしくて、一人で、一人でゲラゲラ笑いながら、できなさすぎて笑えると思ってやってますけど。
# そう、時間がね、取られるし、やっぱ、なんか、しながらってできないじゃないですか、運動って。だから、なんか、どうしても忙しくなったりすると、真っ先に削られる。真っ先に運動を。
# そうなんですよね。良くないと思うんですけどね。年を追うごとにね、動かないと、もう、ほんと、どんどん、危険になってくるじゃないですか。
# ねー、思う。本当ですよね。
# と、すごいですよね。
# だって、あれ、練習して、ステージに立って、あれやったら、まあ、太る暇ないですよね、あの運動量は、と思って。
# ですね。で、自分の運動の方の動画に戻ると、あ、なんだこの、さわー、みたいな、思って、それでも動けない自分がおかしくて。
# クラッチ切ったりとかしなきゃ。
# 駅の階段って結構ありますよね。今思うと。
# こんにちは。
# そう、それ考えると、なんか、ちょっと、二の足を踏むというか、なかなかやろうっていう気にはならなくて。
# いいですね。親子で同じのできると、あのー、話とかもいっぱいできるし、いいですね。
# ね、ありましたよね、なんか。
# そうそうそうそう、マリオね。マリオですよね。やっぱりゲームと言ったらマリオかなって、時代を感じちゃいますけど。
# そんな感じなので、もう、あの、命いくつあっても足りないみたいな、感じなので、人の、うまい人のやってるのを見るだけで、おほーって、冷やかしたいです、私は。
# はーい。ちょっと、チェックしてみようと思います。
# 自由なんですね。
# ダメですね、ちゃんと、かたさないといけないんですけど。もう、なんか、人が、家に来ることも、もう、ここ何年もほとんどない、コロナもあったし、もう、ほとんどないから、もう、自由極まになっちゃってます。
# そんな急にアホなしで来られてもあげられませんみたいな。
# そう、そう考えると、実家はすごいなと思います、その、夫の実家は。結構、開け放、常に開け放たれているというか、いろんな人たちが、
# そう。でも、だからといって、すっごい綺麗になってるかっていうと、まあ、そうでもなくなので、やっぱり気分なのかなって。
# そうみたい。
# ねえ、洗濯物とかしょっちゅう部屋干しとかしてたりするから。フッ。フッ。ダメダメ。
# そう。まあ、だから、こっちも、行く方も、まあ、だから、気楽なので。
# まあ、ありがたいなと思って、いつか私もそっちに振り切れるのかなとか思うんですけど。
# おー、家事、好きな人、ねー、いますけど、あのー、ね、ときめきの人とか。
# そう、その、着手までにハードルがまず上がるし、きちっとやりたいから、こう、ちゃちゃっとやるんじゃなくて、ちゃんとやりたいから、今はちょっとできないとか、で、ハードルも上がるし、もう、ほんと、一箇所きれいにし始めたら、すごい、なんか、こう、同じ場所をずっとこすり続けたりとかして、いじでも、いじでもここの汚れを取るぞ、みたいな。で、もう、息尽きる。
# 同じです。
# してますねー。もうなんか仕事用の机の上とかもごちゃごちゃで、本当はね、あの、目、視界に入るところはすっきり片付いてた方が、きっと集中できて生産性も上がるのかなって、こう、頭では思うんですけど。
# こんにちは。
# そうですね、大会があって、結構、でも、昔はそんな、なんていうんですか、審査員とかもあんまりそういうふうに見方をしてなかったみたいで、昔はかなり全国大会とかで、いい線まで行ってたみたいですけど、
# なんか、それがかっこいいみたいな風潮もあったし、その、ね、その、のめり込んで、青春をやるっていうのがかっこいいって風潮もあったけど、今思うと、もう、ね、3年しかないんだから、そんな本格的にやったって、所詮は3年なんだよと思うと、楽しくやるの重要だよと思います。
# 本格的、本格的にやってたりとかして、マーチングの、あの、マーチングバンドっていうのかな、あの、吹奏楽部が、マーチングをして、その楽器回したりとか、歩いて、体系組んで、やるやつとか。
# ねー、なんか、中途半端にやるぐらいだったら、やっぱり、マネージャーと花形との恋愛の方が絶対楽しい。
# 下手したらだって高校で付き合った人って結婚したりしますもんね。
# マネージャー、花形というか、あのー、憧れの立ち位置ですよね。
# いいですねー。なんか、恋の花が咲きそう。
# かわいい。
# 体大きいとね、うーん、怖い、こわ、怖いかもしれないですね。寄らないでよーって感じですよね。
# パチンッ!みたいな。
# 何歳ですか?男の子。
# ガッチリタイプな。
# 尻尾もスルーッとしてますよね、アビシニアンって。
# 雑種ですけど、全部。全部雑種で。
# そうですね、あのー、全部うち、あの、女の子だったので、それもあったのか、みんな仲は良かったですね。いつもくっついてて。
# そう、してて、引っ越すときに、その、絶対、大変なことになるから、どうしようかなって考えて、そうだ、2匹入れたら、いけるんじゃないかなと思って、で、こう、大きいの買って、何回か、こう、試しに2匹入れてみたりとかして、家の中で、入れてみたりして、ああ、これは、これはいけると思ったら、案の定、いけたので。
# そうなんですよ、初。てか、もう、人生で、多分、最初で最後ですけど。
# わかりますよ、茶色い、茶色くって、結構、敏捷な感じですよね。
# 預けるときも、あのー、普通に手荷物みたいな感じで、あのー、空港の窓口のところで、手荷物と一緒の感じに預けます。
# 多分、大事にされてる。死んじゃったら、だって、大変ですよね、空港の方も。ね、保証とかも、ちょっと、多分、きっと、大変だろうから、神経使ってんだろうなと思って。
# 荷物とかって、よく聞くじゃないですか。違うとこ行っちゃうって。
# 運動量が多い。
# エジプトを感じる子ですよね。
# ね、かわいいですよね。え、一匹ですか?
# 迷う、結構だから、着るまで、かかってたりします。室内に。もうなんか、次に着るものがなくなるまで、かけっぱなしだったりとか。
# そう、そう、空いてる部屋とかになんか、掛けまくって、ほってたりしますけど。
# ねー、ほんとそうなる。しかもなんかもう、動きたくなくなる。
# よろしくお願いします。
# そうですね、ここ数日は雨が多いかなって感じですね。これ多分、雨、梅雨が明けると、7月ぐらいにカラッと、あの、気持ちのいい夏の日差しになるかなっていう感じですかね。
# 8月になると、もう、急激に天気が不安定になって、朝晴れてても、昼ぐらいに突然大雨が降ったりとかするので、なんか、7月ぐらいしか。
# なんか、そうですね、降っても、大雨が降っても、あっという間に上がったりとかして、その、今、最近のって、大雨が降って、大、大の状態が、ずーっと続いたりするじゃないですか。
# そうそうそう、床上?床下浸水とかになっちゃうので、大雨降って続いてると、結構何回もそこをチェックしてみて、まだ大丈夫かなとか、見なきゃいけなくて。
# 怖いですね。
# あっという間に暑くなって、あっという間に寒くなりますよね。
# 確かに、そうかもしれない。その、一番おしゃれを楽しめる季節が、ないかも、確かに。
# 雨の日とかって、その、服とかもすごい、あれですよね、適当になるというか。
# はい。ありがとうございました。それじゃあ、失礼します。
# こんにちは。
# そうですよね。で、そっからはね、就職して、自分のお金で一人暮らしするんだったら、それもアリですもんね。その、身の回りの。
# そうですよね。お金のね、何にどのくらいかかるって、一人暮らししないと気づかないですよね。え、電気代ってこんなんなんだ、みたいな。
# 夢、将来設計についてなんですが、どうですか、あのー、人生設計じゃないですけど。
# 私とかも一人暮らし初めてした時とかは、あの、夜、なんか、飲み物飲んで、机の上にコップとか置いたまま寝て、起きた時に、あ、そっか、誰も片付けてくれないんだって気づくみたいな。
# 気づきますね。なんか、そういうのは、やっぱり、その、さっきほどの案で経験できるから、すごい、すごい計画的で、すごい、なんていいアイデアなんだろうって、ちょっと感動してます。
# 将来のこととか考えたりとかされてます?
# 自分たちが、言って。
# 画期的。
# しかも、親御さんの面倒も見れませんもんね。
# ありがち。
# 計画が。
# そう、みたいで、結構、庭いじりは、好きでしてて、何をしてるわけじゃないんですけど、ちょこちょこ、なんか、むすってます。雑草。なんか、すごい、暗い人みたいなイメージだけど、そんなことないんですけど。
# そうですね、なんか、今、賃貸なんですけど、一見、あの、前に住んでた方がお花が好きだったみたいで、その、結構、鉢植えじゃない、鉢植えにその方は植えてらっしゃったんですけど、こぼれたみたいで、結構、いろんな花が、いろんなところから生えてくる。勝手に生えてくる。
# なんか、パンジーみたいなのが生えてきたり。
# 住環境についてですが、どうですか?今、ご自宅は、えっと、一軒家ですか?それともマンションとかですか?
# すごいことになってて。
# これ、だめでしょーと思って。
# 大変なことになってましたっていうのをちょっとふと思い出したところで、お時間が来てしまったようです。
# とても楽しいお話をありがとうございました。
# うちも庭、すごい猫の額ほどの庭ですけど、なんか育てたりとかしてます?ガーデニング。
# だから、あの、芝生とかは植わってはいるけれども、何かをその、育ってるってことは、お花ぐらいは何とかぐらいな感じで、野菜を育てられるような土を作れる環境じゃないので、いいなーって感じです。
# そうですね、たぶん、ま、昔に比べたら食べれなくなってるかなとは思いますけど、食べちゃいますね。本当はね、食べて後悔する感じです。しばらくした後に。お腹がはち切れるとか。
# すごーい。
# 怖くなっちゃいますよね。
# なるほど、日本食になったら、あんまり意識しなくて、
# なんか、意外ですね。
# 塩ですよね。
# しないしない。
# そっか、お米じゃないから。
# そんなことが。
# 油と糖と塩分と。
# 普通、ひと玉じゃないんですか?
# 食べること。
# どうですか?食べること。
# よろしくお願いします。
# すごい、それ、社風がすっごいいいってことですよね。その、戻ってこようって思えることもすごいし、それを受け入れる体質もすごい、いい。
# そうなんだ。
# そこはありますよね。
# 研究だとそうですよね、でも研究だとね、だって、予定通りとかいかないですもんね。
# 場所を変えて、
# 秋が来る。
# あっ、すいませんってならん。
# 電車の中でぶつかったりしてる時に、あの、こう、なんていうんですか、うん、とかやる人、あれこそなんか私的にはマナー違反だよなと思うんですよね。
# でも、開けてると、私もちょっと、え、それ、座ろうよ、と思います。そしたら、一人分のスペース開くから、みたいな。つり革も、私、つかまれるから、って。
# いいですね。
# ありがとうございました。
# ある、あるある。
# んんんんん。
# 確かにね、雑草がね。
# 今出た、その、組合とかが、マンションは、大規模マンションになると、組合がなかなか大変かなとは思います。その、爽快?
# 管理組合?あのー、修繕とかあるじゃないですか、マンションって、定期的に。で、それで合意するのがなかなかね、いろんな世帯があるから。
# もうね、おっきいマンションは、ほんとうぞうむぞうですもんね。
# でも、一見や寒くないですか?冬とか。
# ちょっと下焼けっぽくなりましたもん。
# マンションは、全然、あれですよね、窓さえ閉めてれば、結構、暖かい、冬とかでも暖かくて、
# マンション、あれですか、あのー、教養施設とかもあるようなマンションですか?スポーツジムとか。
# わかる。
# もう、すごいつらかった記憶があって、それがあるので、まあ、マンションに住むなら低層階というか、あの、低いマンション?2、3階建てぐらいの低いマンションに住むか、かな、1階に住むかなと思ってます。
# たぶん、住む機会はないだろうけど、憧れますよね。
# お時間が来たようです。はい、ありがとうございました。
# 強要の、
# かっこいいけど、日常、日常生活的に必要かと言われると、そんなことはないと。
# こんばんは。
# 私も、
# まあ、確かに、確かに、だって、ね。
# 日本の未来。うん。最近ね、どんどん、あのー、技術が変わっていくから、どうなっちゃうんだろうと思ってます。あのー、自動運転とか、車の。
# そうですよね。なんか、そこまで言うんだったら、じゃあ、もう、制服あった方がいいんじゃないかって思っちゃう。
# え、ど、どんな感じだったんですか?え?髪の毛?
# とか、そういう、セキュリティ的。
# 使っちゃって。
# うち、夫の会社は、営業用のカバンは、あのー、支給が出ますよ、あの、お金が。
# だから、まあ、しょうがないのかなと思って、まあ、経費で落ちるらしいです。
# ね。
# いいなーですよね。だって、会社のカバンって、結構な値段しますよね。会社用のカバンって。
# ファッション用のその、ど、ね、ちっちゃいその、お遊び用のカバンとかだったら安い、ピンキリですけど、会社用のちゃんとそれなりの大きさがしてしっかりした作りのって選んだら、1万とか軽くするから。
# そんなのをちょっと出してって感じですよね。経費でしょ、経費って感じですよね。
# むしろ、反抗的に。
# いや、でも、誰もまも、守ってない。
# 難しくないですか?合わすのが。
# そう、でも、一時期、結構、編みタイツの、その、細かい編みのやつ、ちょっとお上品な感じのが、流行ってた時代があって、普通の人も履いてるみたいな時代があって、履いてきてる人とかいって、ちょっと、でも、やっぱり、あ、編みタイツって、こう、こそこそ言う、言うちわたりしました。
# 焦げる、焦げる。
# 大きい、なんか、花柄のスカートとか、セレブーみたいな、
# またルーズソックスの時代が来るかも。
# はい、ありがとうございました。
# 冒険しちゃう。
# お願いします。
# あと、ダムとかもなんか、あれですよね、観光スポットとかになったりしますよね。黒部ダム?とか。
# まだ寒いんですか?あっちの方は。
# あれって、でも、そんなに北の方じゃなかった気がするんですけど。
# そういうことなんだ。
# ダムカードとかあるんですよね、確か。
# ちょっと、ダニが、その、ポイントがまだ私にはわからないですけど。
# 私もないですけど、ちょっと、あの、あれはスタンプラリー化してますよね。
# 穢れてますもんね、仏は。あの、死んでる人のやつだから。
# ツアーとかやってくれるんですよね、確か。あの、ツアーっていうのかな。あの、ガイドさんがついてくれる。
# 私もよくわかんないですけど、って人だけど。
# やっぱり、気になります?ホテルとか、気になる方ですか?
# そうこうしてる間に、その、だんだん臆病虫が出てきて、なんか、もう、行けない、怖くて行けない、海外、とか、思って。
# そうなんですね。
# そうそう、そう、そんな感じがします。
# はい、ありがとうございました。
# え、知らない。アホいんだ。
# いいですよね。どのぐらい泳いでました?
# 運動も、陸上の運動もやりつつの、水泳もやりつつの、
# 私、球技すごい苦手で、あのー、ね、あんな細いバットに、こんなちっちゃいボールを当てるなんか、そもそもむず、無理なんじゃねーの?と思ってるって思うんですけど。
# 誘われますよね。
# 無理無理無理。だって、どのタイミングで、その、飛び越えればいいんだっけって考えちゃいますもん、まず。
# そうですね、小学校ぐらいで、もう、習うのはやめて、感じですね。でも、泳ぐのは好きで、まあ、バタフライはできないまま終わったんですけど。
# 仲いいんですね。
# はーい。漫画。漫画はどうですか?結構読みますか?
# ワンピースとかってことかな、それは。
# もう全然違う方。
# 私も、なんか、アニメと漫画と、その、なんか、こう、つまんで読んでってるから、ちょっと、字系列がいまいちよくわかってなくて、で、一番、なんか、感動して読んでたのって、なんか、そういう長いやつって、いつもそうなんですけど、最初の方が面白いけど、だんだん、
# すみません、大人なのに、漫画好きです。アニメも好きです。
# 忘れちゃったけど、ダチョウ、ダチョウ?ダチョウなのかな?
# 確かに、ちゃんと起承転結がね、あるから。
# わかんない。ガラスの壁なんか、結構、言ってそうな気がする。
# 子供世代みたいな、その、ドラゴンボール的な進み方しないと、
# 少女漫画ってあんまり、私、少女漫画読んだ記憶が、君に届け、あれ、君に届けとか流行ってましたよね。
# 技術大学って言うんですかね、芸大、芸大に行っている子たちの話だった気がします、ハチクロは。
# 最近はやっぱもう、なんだかんだ言って鬼滅の刃なんじゃないですかね。でもあれはアニメが流行ってるって感じですからね。
# アニメが、また、第2期が始まるらしくって、
# 結構前、結構前だと思うんですけど、また始まるって最近聞いて、ちょっと楽しみにしてたりとかしますね。
# 保存がきくやつで。
# おいしい。なんか、そう、砂糖を入れてもなんかおいしいって噂は聞きましたよ。
# 塩じゃ、なかった気がします。砂糖で、なんか、ネバネバが、なんか、ふわふわになる感じ、らしくって、まあ、ちょっと、チャレンジして、たくさん入れちゃだめだけど。
# そう、ちょこっと入れてみて、ちょっとチャレンジしてみてください。
# すごい、えらい。
# それはちょっと引っ越せない。じゃあ、定期的に。
# インスタントラーメン。
# 学校について、お話をしていこうかなと思います。学校、学校と一口に言っても、小中高、その後とかもあるかと思うんですけど、どうですか?あの、一番思い出が多かったのって、どの辺の時代でしょうかね?
# そうですね、やっぱり一番楽しかったのは何も考えてなかった小学校ですかね。
# でも、剣道、剣道ってことは、試合とかもあったってことですか?
# そうなんだ。うまい人って必ずキーって言いますよね。
# でもうまいんですよね。
# でも、でも、どうなんですかね、なんか、上手い人は、上手いんですけど、私とかは全然、もう、設計描いてみたいに言われても、よく分かんないから、なんか、適当に描いて、釘を打ちながら調整するみたいな感じで、少しずつ削ってみるみたいな感じで、作ってましたけど。
# なんか、すごい、そういうの聞くと、あのー、人間、動物なんだから、勉強も大事だけど、そこ、ね、そこを学ばないとまずいけないよねって、ちょっと思いますね。
# よっぽど、よっぽどですね。え、高校1年の時から、もう受験に向けて全力疾走って感じなんですか?
# そういうもんなんですか。
# 倍速。
# やり方がね、
# さっきはその、場所で分けてっては言いましたけど、でもやっぱり、どの舵についても、お互いやっぱり多少の妥協をしながら、お互いできるっていう状態にしておくの方が、スキル的には高いのかもしれないですね。
# そうですね、あんま、あのー、男女平等じゃないですけど、ね、性別に関係なく。
# やっぱりこだわりが強い方がやるみたいなのはあるかもしれないですね。
# 使われちゃってる、みたいな。あるから、ちょっとね、その、難しいですよね。あのー、ちょこっと手を出すっていうのは、やっぱり難しいのかなって思いますね。やるならやる、やらないならやらないっていう方が、台所は特に強く出るかもしれないですね。
# すごいですね、かける、熱意が。
# そうですね。え、その他の、その、房室以外は、あのー、あれですか、ご家族がこだわったとか、そういう感じなんですか?
# 今、もう、多いですよね。うちも二重窓に、後からしました。
# うちも、その二重窓をつけてもらったその、その日の昼の時点で、もう、あれ、すごい静かなんだけどと思って、あれ、なんかすごいしんとしてるって実感しました。
# うち、あったのかな?なんか、その辺、全然考えずにやってしまった気がします。
# 部屋ごとに色が違う家とかあったりして、ちょっとびっくりしたりします。
# すごいですね。
# それは、あの、ピアノの練習中に家族がちょっと、ちょっといい加減にしてとか言ったりすることがあったりするんですか?
# こんばんは。
# でも、小豆はね、体にいいって言いますもんね。あの、赤いのってポリフェノールなんですかね。
# 私、入れない派です。
# やりますね、はい。ざる、ざるに。
# 結構18になるとかなりしょっぱいですよね。
# 当初のね、あのー、バタバタなくなっていくっていうような、その、毒性の強さっていう意味では、確かにちょっとね、変化して、そうでもなくなったのかもしれないですけどね。あんまりそこまで恐れなくても。
# もう、いろんな意味、なんか、制覇してそうですね。
# でも、30とか言ってる人、相当いないですよね。で、パスポートとか、あの、ハンコだらけってことですか?
# ギリギリって感じでしたね。
# お願いします。
# 逆走しちゃいそう。
# そんなもんだったんですか?
# もう、GOって感じですよね。行っとこう、みたいな。
# 違反料金とかも、すっごい高い国とかってありました。
# お金で。お金で解決。
# ということで、えっと、お時間もよろしいようなので、今日はこの辺で失礼致します。
# それは幸運ですね。
# もうすぐ梅雨も明ける感じなんですかね。
# でも、今住んでるところは、あのー、あれなんですよね。海に向かって、そのー、低くなってる地域なので、やっぱり、ちょっと、その、ハザードマップ的にも危ないし、雨が降っても、やっぱり、ちょっと危険感は毎回感じますよ。なんか、こう、ぎりぎり、ぎりぎり、今回はもう大丈夫だったみたいなところを、いつも、すれすれを言ってる感じです。
# 台風もね、結構ひどいですよね。台風とか、備えたりとかされてますか?あの、避難の、避難リュックとか。
# うちとか、やろうと思っても、結局、なんか、中途半端な状態で、ちゃんとは揃ってなくて、やっぱちゃんとしなきゃいけないかなって、その、雨とかがね、最近ひどいから、こんな何年かとかはひどいから、やっぱりちゃんと、ちゃんと備えとかなきゃなと思いつつも、ちょっとまだ全然やってませんって感じです。
# あれですか、お住まいの地域は、結構、冬は雪が積もる地域なんですか?
# 私、ずっと関東で生まれ育ってたので、冬は天気が良くて、耳がもげるぐらい、風が冷たいっていう冬ばっかりで、今、それで日本海側に住んでるので、雪は結構降ります。冬は。
# 盆地って夏、激アツじゃないですか。
# あと、でも、最近結構、あのー、静寒剤っていうのかな、あのー、汗を抑えるやつ。
# だから、結構、あの、しゃばしゃばしゃばしゃばしゃばとかやって、乗り越えたりしてます。
# わかんない。私、結構、スプレーとか、もう、暑い時とか、顔の範囲に、この辺に、シューとかやん、顔、顔冷やすとか。
# え、急に宅急便とか来たらどうするんですか?
# 待った、待った、待った。
# ねえ、ありえないですよね。体温より暑い気温って。
# それでも結構、おっきいですね。そんなもんか、おさぎって。
# そっか、そっか、垂れてる子いる、確かにいる、いる。ど、どういう感じなんですか?お買いになってる、買ってるやつは。
# そうなんですね。い、色は、色は、茶色。茶色。
# ねー、あれ、でも、好きな人からすると、リアルファーって言うんですよね。
# あれは、どうなんですか?
# なんだろう、ちょっと、切ないなー、それ。
# え、そうなんだ、なんか、あんまりそんな凶暴なイメージがなかったから、ちょっと、あれですけど、うさぎってバトルするんですかね、うさぎ同士で。猫パンチ的な。
# ブーっていう。ええ、そうなんだ。なんか、猫が喉を鳴らす的な感じなんですかね。
# そうなんだ。どういう時に泣くんですか?泣く時って。
# 怒ってるんだ。かわいいけど。
# かじたりとかされません?ガブッとか。
# 私も、こう、遠い知り合いで一人いるだけで、あんま基本的にウサギ、あんま聞かないかも。
# すごい、交代宮ですね、うさぎ。ある意味だって、その子の部屋ですよね。
# そのぐらいの交代具で自分の部屋ももらえて、ご飯も、ヘルシーなご飯ももらえて。
# オルフ版の時もちゃんと人が来てくれる。え、めっちゃ手厚い。
# いるってだけで、なんか、心が満たされるの、すごいわかります。
# いいですね。というところで、お時間が来たようです。今日はありがとうございました。
# はい、それじゃあ、失礼します。
# こんばんはー。
# 絶対入れるアプリとかあります?変えたときに。
# そうなんですね。でも、なんか、YouTube、スマホで見ると、すっごいちっちゃく感じません?私、結構、YouTubeはパソコンの、あの、モニターで見る方なので、たまに、
# 賢いかも。あれ、あっちこ、なんか、あれですもんね、アプリいろいろ入れるよりは、YouTubeでやっちゃった方が、確かに、いいかも。
# 食事とかするときとかでも、つい見ちゃいますよね。
# しますねー、しますします。でも、今まで私、結構、家事をしながらは、Spotifyで音楽聴いたりしてたので、ちょっと、今日、YouTubeって聴いて、あ、YouTubeで聴くって、ありだなって思ったんで、ちょっと、YouTube派になってみようと思いました。
# スポーティファイだと、結構、それでCM入るので、で、がっつり入ったりとかする、して、いつの間にか、なんか、ラジオとかに変わってたりとかするので、
# いや、違う、音楽じゃない、とかなるので、ちょっと、そっか、YouTube、いい案を聞いたところで、お時間が来てしまったようです。
# 今日はありがとうございました。
# こんばんは。お願いします。
# そういうものなんです。そういうもの。
# それ、あの、国内でやってるだけだったら、まだ全然いいと思いますけど、海外の人と日本の人がそれ、ラグビーでやってると、それこそ、ほんと、すごい大変なスポーツってことですね、そういうルール。
# すごい、なんか、スポーツのために留学するっていうのはわかるんですけど、語学留学を目的にスポーツをやるって、すごい、画期的な発想。
# なんか、しゃべる、チームでしゃべるスポーツって、野球がそういうイメージだったんですけど、チームワークをすごい。
# うーん、なんか、そのイメージだったんですけど、で、ラグビーとか、どっちかっていうと、寡黙な男の人たちが寡黙にこう、ガツッ、ガツッってやってるイメージだったんですけど、実は違かったっていうことで、ちょっとそういう視点。
# でも、そうかもしれないですね。野球は、特にプロとかは、ね、トレードしてやってるから、個人が重要なのかもしれないですね。
# まあ、確かに、ジムだと、もう、結構、一人で黙々と、ただ、こう、動くっていう感じですもんね。
# そうですよね、場所もそうだし、仲間もなかなかちょっと集まりづらそうな気が。
# ね、よく考えたら、ブラックすぎますよね。1時間。
# ね。
# そんなきついんですね。なんか、きついきついとは聞くけど、そこまでとは思ってなかった。
# でも、結構、たまにって感じなんですか?私的には、なんか、それが普通なのかなと思って。それができなかったら、なんか、あの、お昼とか、またいでるときとかは、あの、飲み物とか、渡したりとかしてるのが普通かなって。
# そういうもんなったんですね。なんか、全然、そう、私、結構、子供の頃から実家が引っ越しが多かったので、なんか、親がやってるのを見て、それが普通なんだと思ってたので、普通にやってました。
# 今日はありがとうございました。
# 私なんかもう、アルバイトの代表格をなんか、そうなめしましたみたいな。
# はーい。
# 教科って何教えてらっしゃったんですか?
# すごい、苦手なのに教えることができるって、すごい、すごいですね。
# けっこう、おっきい力ですか?大容量。
# あれですか、折りたたみ。うん、折りたたみとかちゃんと持っていく方なんですか?
# なんだろう。え、折りたたみ傘とか入れてるから重いのかなと思った。
# でもパソコン入れて、あれ、心配になりません?なんか、ガッ、ガションとかって。
# 厳重に。
# 結構、いろいろありますもんね、リュック。あの、カチッとしてるやつもあるし、あの、ゆるいやつとかもあるし。
# いっぱい、ポッケがいっぱいあるの、ちょっと嬉しいですよね。私だけかな。
# あります。でも、鍵、家の鍵とか、ポケないとすごい不便です。
# はい、お願いします。
# まねる。
# やっぱりね、CookDoすごいですよね。
# でも、マーボー豆腐は結構いけ、いけないですからね。自分で作っても。
# なんかね、和風、和風な麻婆豆腐ができて、結構、鶏ひき肉とお豆腐で麻婆にしたりしてて、それを、そう、それをご飯にのせて食べると、で、まあ、人には見せられないけど、ぐちゃぐちゃとして食べると、ね、おいしい。人には見せられないけど。
# そう、そう、はじめしってやつですよね。
# 結構ちゃんとやってるって感じなんですかね。え、今お一人暮らしでしたっけ?
# あと、うん、やっぱり、入らないでっていう場所というか、もう、最低限のその、リビングと、きゃ、客間みたいな感じで、そこ以外はこの、ガードして、通さないように。あ、トイレはそっちだよ、みたいな、感じで。あ、迷子にならないでね、うちで、と思いながら、やりますけど。
# あと、間違ってこう、ガバッとか開けられたら、ちょっと困るので、トイレはあっちね、洗面所はあっちね、みたいな感じで、やったりしますけど。
# じゃあ、なんか、あれですね。ちっちゃいと掃除もそんなに大変じゃないって感じですかね。
# 失礼します。
# えらいー。
# でも、ちゃんと、朝、っていうか、朝も、朝も準備するのめっちゃ偉くないですか?むしろ、むしろ、朝、朝、手、抜きたくならないですか?
# めっちゃいい人。
# こんばんは。
# 油浮いてるっていう、うん、感じがしますね。
# 宮崎行ったことない。結構、九州でも、下の方、下の方、南の方って、あれですよね。
# お願いします。
# なんか、九州にいて、新幹線に乗ろうっていう、その、心が、なかなか、なんか、車移動したくなりません?九州だと。
# 沖縄行ったことありますか?
# もう、長いこと、コロナ関係なく、長いことをしてなくて、
# 計画というか、野望。
# でも、どうだろう、私はずっと、関東、東京近辺で生まれ育って、で、今、九州にいるって感じなので、もう、九州のその、北の方の海は、それでも綺麗だなって思いますよ。
# わかる、やっぱり、海、いいですよね。見てるだけで、おおーってなりますよね。
# そうなんですよ。そうそう。だから、事前学習する時間があったら、そっちも楽しめるかなと思うんですけど、やっぱり、あれですよね。パッといって、もう直感的に、うおおーってなるのは海ですよね。
# 行きたい、私も行きたいです。
# 留学?
# そうそう、物理的に、そこのコントローラーがあるところで、二人でやるっていうのと、あ、あとでも、あれもありましたよ。あの、マットみたいなのを敷いて、ジャンプしたりするやつ。
# そうそうそうそうそう。
# でも、ほら、次、もう出てはいますけど、もう、次の時代のゲームはVRとかじゃないですか。あれになったら、また、なんか、面白そうじゃないですか。私は、あれを、もっと安く、もっと市場に早く出回らないかなって、ちょっと待ってたりします。
# そう、そうそうそう、そうなんですよ。だから、楽しそうだなと思って、なんか、指先だけでやるのは苦手だったけど、なんか、それだったら。
# じゃあ、ゲームあんまりやらないってなると、ま、漫画派?漫画?漫画で時間潰す。
# やります、やります。
# 完結してないんですか、まだ。
# ちょっと、うらやましいな、行ってみたいとか、思いました。私もその漫画喫茶行かせてください。
# 天国じゃないですか。
# それはショックかも。
# 時代かな?時代かもしれない。
# なんか、何が楽しいのかって言われると、ちょっとあれですけど、で、僕こう、あれでした、いろんな刺繍してる人、結構いました、その、学欄の内側に。
# いや、違う違う。違う、えっと、どうだろう。どうだろう。でも、制服売ってるところでやってるんじゃないですか。わかんない。ダメ、ダメかな。
# もぐりでやらないと、だめなのかも。
# どうですか?中学校、中学校、あれじゃないですか?恋愛とかどうでした?恋愛事情は、周りは。中学。
# 確かにそうかも。高校とかだとね、バイトできなかったりする学校が多いから、マネージャー職とか、人気があったけど、大学は確かにそうかも。
# なんか、挑戦状、果たし状みたいな感じじゃないですか。
# 練習試合みたいな感じですね。
# 楽しそう。今でもなんか、サークル、サークルじゃない、その部活の人たちとかと、会ったりとかしてますか?
# なんだったら話をしてない時もあるって感じですよね。
# でも、中学楽しかったって、ちょっと、珍しくないですか?だって、中学って、思春期真っ盛りじゃないですか?一般的には。
# そっかー、部活楽しいと確かに、中学は楽しいかもしれないですね。
# こんにちは。よろしくお願いします。
# その、コーヒーとかの、その飲み物とかもそうだし、あと、なんか、純喫茶、昔の、なんか、マスターがいるような、ところとか、そういうところとかも知ってそうですよね、その、いろいろ言っている方だったら。
# 案外、その、辛口な口コミを信じてみた方が良かったりするかもしれない。
# 東京ね、あのー、多すぎますからね、カフェ。
# そうですね、基本、電車移動だから、ちょっと、ちょっと一休みしたくなりますもんね。
# あれですか、あのー、カフェ行かれたら、店内で飲む方ですか、それともテラス席があったら、テラス席、進んでいく方ですか。
# 確かに、今おっしゃって、確かに、あのー、ソファーとかこだわってるお店もありますよね。
# こんにちは。よろしくお願いします。
# キャバ嬢、そうですね、あのー、キャバ嬢のなんか、テクの本が出てそうな気がしますね。その、しゃべりテクの。
# こんな気がします。でも、一番は、やっぱり、その、下ネタを言うときとかも、緊張して言うと、すごく、その、さっきの政治家の下ネタっていう風に、雰囲気が、そうそう、なんか、すごい違和感が出ちゃうので、あんまり、その、性別を意識せずに、スコンと言ってしまった方が、爽やかで、こう、スルーできるかもしれない。
# うまく、苦手意識があるのって、緊張して、その、頭が真っ白になっちゃうっていうのか、それとも、相手のなんか、反応が気になるとか、相手を楽しませる方法がわからなくて悩むとか、ど、どんな、具体的には、なんか、どんな感じとかありますか?
# 確かに確かに。キャッチボールにならなくて、膨らまなくて、終わっちゃうと、また次の話題考えなきゃってなって、こう、だんだんネタがなくなって、てんぱりますよね。そう、わかります、わかります。ある、ある。そうですね。まあ、異性に限らないかもしれないですけど、どうなんでしょう、あの、同性と話すときは、そんなことにはならないんですかね。
# こんにちは。お願いします。
# こんにちは。よろしくお願いします。
# はい、今日はどんなお話をしましょうか。
# いいじゃないですか、でも、その、ガチでやるのが楽しい。真剣になるほど楽しいという。
# 確かに、見方がね、変わるかもしれないですね。実際に自分がやってみると、その作家さんが、作曲家さんが何を考えてたのかとかも、ちょっと、見えてくる世界が違ってくるのかもしれないですね。
# 作曲を、曲を一個作るっていうことも、まあ、目標の一つかもしれないですけど、得るものはもうすでに得てるっていう感じもしますよね。
# モノマネだけじゃなく、自分でもというと、
# こんばんは。お願いします。えっと、今日はどういったお話をしましょうか。
# そうなんだ、じゃあ、もう、何回も、それを乗り越えて、え、すごい。そうなんですね。でも、なんか、何回もやってるうちに、どんどん上手くなりそう、同じところを通るたびに。しゃく、ちく、しゃくしくと、その、スキルアップしていきそう。
# でも、そうですね、当時、すごいワクワクしたでしょうね。
# 私、ゲームすっごい下手くそだったので、はい、あのー、マリオすら、スーパーマリオ、初代スーパーマリオすら、あの、制覇せず終わったので、フフフ。
# あんま、もう、その、全く知らないタイトルで口コミとかを頼りにいくっていうよりも、昔知ってて、ちょっと、ちょっと雰囲気が分かるやつとかから、こう、チャレンジしてみると、自分が今やりたいのが、この、明確になってきたりとかするかもしれないですね。
# 確かに贅沢ですよね。いろいろやりたいのがたくさんある。やりたくないのばっかりじゃないから、なかなか楽しそうですけど、選ぶのも。あれですか、あの、子供の頃にやっていたのは、何系がお好きだったんですか?その、いろいろ種類あるじゃないですか。あの、RPGだとか、シューティングだとか、なんかいろいろあると思うんですけど、何系とかありました?
# なるほど。そっか。昔のやつ、今おっしゃってた、その、昔のやつで、一人プレイのデーとかって言ったら、なんか、そういう、なんていうんですか、夏メロじゃないですけど、なんか、そういうのを集めたようなやつって、なんか、出てなかったでしたっけ?
# そうなんですね。えー、めちゃめちゃ環境が整ってるじゃないですか。
# すごーい。トライリンガルの次。
# でも、お料理屋さんがあって、そこの現地の方が働いてらっしゃるっていう風に考えたら、あれですよね、メニューとかで、その、現地語に触れる機会もあるし、あれじゃないですかね、その、書いてかっこいい系を攻めてみるっていうの。
# なるほど、そうなんですね。じゃあ、もう、本当に生きた言葉を喋ってるってことですよね。学校で習ってとかじゃなく。えー、すごーい。お仕事か。お仕事、そうか。お仕事、お仕事系で探してみるっていうのもありかもしれないですね。そのー。
# おいしいですもんね。お酒飲みながらつまみって、なんであんなにおいしいんでしょうね。
# わかるー。おなかすきますよね、なんか知らないけど、アルコール飲んだ後。
# じゃあ、あれですよね、でも。
# だめだ、だめだめ。それは、どんどん、なんか、健康から遠ざかってる気がします。
# なんだろう。でも、途中でやめられないですよね。ポテチ。
# んー。
# 思いますね。運動不足なのか、何なのかわかんないですけど、お腹出ますよね。
# 例えば、ほら、あのー、愛嬌があるとか言うじゃないですか。だから、こう、まあ、接客業の人は基本的にそうだと思うんですけど、基本、笑顔、とにかく笑顔みたいなのは、まずやっぱり、コミュニケーションの基本の木なのかもしれないですよね。
# 自己開示ね。自己開示をして、相手の警戒心を緩めさせるっていう作戦ですね。
# やっぱり、その、天気系で、今日は、こう、こう、こう、こうで、自分はこう感じてます、みたいなところから、こう、相手が、その、暑いの好きな人なのかとか、いろいろ、その、相手の開示を促してみるっていう作戦はどうでしょう?
# 痛いパターンだ。
# 香辛料じゃないですけど、香りのですよね、独特の。確かに。そうなると、やっぱり、あれですか、あのー、料理作ろうって思ったら、あの、まずは、本とか、ネットとか見て、作り方を調べる感じなんですかね。
# 準備万端で挑みたいと。
# ご家族に作りたい。
# 辛そうに見えて、辛くないとか。
# ちょっと、米物が欲しい感じですよね。春巻きがあったら。
# ごま油入れたら何でも中華になるとか言ったら、だめ?
# あ、そうだ、だめだ。お、だめだ。あ、そっか、そっか、ちょっと、だめだ。邪道すぎた、今のは。却下。
# どうだろう?
# オイスターソース、美味しいですよね。
# 取材ね、思いつかない。そうだな、難しいな。
# ピザだったら、ほら、最悪、ピザのね、あのー、生地売ってるから、トッピングだけ考えればいいとか、なるかもしれないっていう、どうでしょうかね、こんな感じで。
# こんにちは。
# よろしくお願いします。
# で、結構、威厄してるらしいので、その、あのー、字幕そのものが絶対正しいとは限らないので、自分で調べなきゃいけないことも、まあ、あるかなとは思います。
# そういう映像をちょっと使ってみる。今はね、もうなんか、YouTubeとかいっぱい転がってるから、無料で見れるし、いいかもしれない。あと、
# イギリス、はい、はいはい、どうぞ。
# はい、ありがとうございました。
# 結構、あれですよね、そうなると、しっかり、しっかり勉強したい感じですね。ちょっと日常会話ができるとか、そういうレベルではなく、
# どんな系のお話だったんですか?ラブストーリーとか、アクションとか、サスペンスとか。
# 難しいけど、そっか。でも、謎が、謎がある感じですかね。
# そうするとあれか、あのー、洋画とかでも、あんまりシリーズものみたいになってるのは良くないのかもしれないですね。
# エイリアン対プレデターってやつも出てたけど。
# 早い、早い、涙腺、涙腺が緩くなるの早すぎる。あと30年後ぐらい。
# じゃあ、絶対あのー、タイタニックの古いバージョン、累戦、あの、崩壊すると思います。
# ね、それもいいし。
# ありがとうございました。
# どれだろう。
# ドラッグストアとかに売ってると思うんですけど、ああいうので全然構わないらしくって、
# ただ、どうだろうか。
# それ以外に、あるのかな?
# なんだろう、私も、私も、針が欲しいなと思うから、何も、なんかいい案があったらむしろ聞きたいって思っちゃうけど。
# ゴシゴシしちゃうと、顔の皮膚って、体の他の皮膚と違ってすっごい薄いので、なんか、ゴシゴシすると、もうそれだけ、たぶん、痛むというか、きっと、ハリとかも、それで、あのー、ゆるんだりするんじゃないかなと、ちょっと思いました。
# あとは、あれですかね、家族でいろいろなんかこう、化粧品というか、スキンケアをちゃんとやってる家族とかがいたりしません?
# そういうのは結構男性も使ってるって聞いたりしますよ。
# だから、あの、もちろんね、冷やかしみたいにして聞いたら送ってくれないと思うんですけど、買う気満々で、やりとりしてると、結構、試協品じゃあ一緒に送りますよとかって言ってくれるらしくって。
# だから、それで、そういうのを、あの、ネット上のお店で相談してみるっていうのは、やってみても損にはならないと思います。無料だし。
# 乾燥するとあれですもんね、あの、かゆかったりとかし、ね、痛かったりとかしますね。冬とかね、大変ですよね、乾燥肌だと。
# みんなこっそりやってるんですね。
# ありがとうございます。失礼します。
# ハット麦のあの、化粧水、いいですよね。安いし。
# こんにちは。
# いいですよね。
# ソロキャンの面白そうなところって、面白そうっていうか、良さそうなのって、こう、キャンプグッズっていうんですかね。
# ソロキャン、めっちゃいい、いい趣味になりそうな気がします。
# 外で料理して食べて帰ってくるっていうキャンプ好きの人もいますよ。
# 三角のはやっぱり昔ながらで、結構風をちゃんと受けないような作りになってるし、あと一人で立てやすいらしいです、その三角だと。
# ほんと一人用テントだから、一人でポール立てて、かぶせて、周りにペグで止めるだけとかって言う。
# だから、ね、夏とか大雨降ったりしたらちょっと怖いじゃないですか、一人で山にいて。
# 確かに、確かに。ええ、いいじゃないですか。
# 涼しくなってからね、天気も安定してきてから、今のうちからでも、あのー、あれじゃないですか。
# 確かにね。じゃあ、やっぱり、夏は日帰り。
# そろそろお時間もよろしいようなので、これで今日は失礼したいと思います。
# 近所でも、結構ありますもんね、神社って。
# そういうこと。
# あります、あります。
# すごくないですか?3ヶ月で9キロって、す、すごいペースですよね。
# でも、10%でもすごいことだとは思うんですけどね。10%落ちるだけでも。
# 9キロ落ちたのに対して、9キロってすごい大きいから、ちょっとあの、もうちょっと期待したいところでしたよね。
# で、ダイエットとかでよく聞くのは、その、一旦停滞期に入った時に、あのー、筋肉を作るための食べ物をちゃんと食べる。あのー、食事制限で食べなかったっていうのを一旦ストップして、その、タンパク質?あのー、なんだっけ、タンパク質だっけ、あの、赤身のお肉とか。
# 今まで、まあ、炭水化物を、まあ、抜いて、抜いてというか、減らしてきて、で、いよいよ筋肉を今度はつけていくってなったら、ちょっと、お肉系にこの食事を変えてみるのはどうですかね。
# ぜひ、ぜひ。
# 食事管理から若干ズレちゃいましたけど。
# 全然、全然、なんか、正解な、それ正解な気がしますね。
# はい。あの、普通の化粧水は水に対してちょっとこう、ぽたぽたぽたっと美容成分を入れてるのに対して、SK-Ⅱは、あれ、液自体が、あのー、何だったかな、こう、なん、なんたらピテラとか、なんか、CMでやってるじゃないですか。
# あれなんか、お酒かなんかから、こう、発明したっていう、あのー、酵素液みたいなやつ。あれ100パー、そのー、それの液なので、あれをすっごい大事に、少しだけ、気になるところだけに、つけるっていうのだけでも、そのー、美容液使いっていうんですか、で、いいって聞いたことあります。
# それをやって、こう、引き伸ばして使うのでも結構効果があるって聞いたので。
# もし、気になるところがあるんであれば、今のにプラスして、そういうちょっとお高いやつを自分へのご褒美で、うん、やっても。
# そう、もうやっぱり地球、地球規模でやっぱ環境がやばいことになってるので、今、今もうみんな子供を塗ってますね。
# はい、今日はどうもありがとうございました。
# ただ、でもやっぱり、この、もうなんか、30年前とは違い、この、今の日本、ね、あの、日焼け止め塗らないと、ちょっと太陽がやばいことになってる気はするので、まあ、日焼けは必須かなっていう、あ、日焼け止めは必須かなっていう気は、まあ、するんですけど、あとは、あれですかね、保湿?
# いいじゃないですか。結構、あれですよ、あのー、カラーコーディネーターさんっていうのかな、あの、ネットとかで、フリーの人が、あのー、募集して、募集っていうのかな、その、お家でやってらっしゃったりしますよ。
# あ、上がりますよね。化粧とか、新しい化粧とか教えてもらったら絶対上がりますよね。
# 色味はきっと、当時のことを思い出してみるっていうのもありかなって。
# はい。ということで、今日はこの辺で終わりにしたいと思います。
# えらい、えらい。
# ちょっとちゃんとしたのがないっていう。
# あとはその、自分、自分の気持ちですよね。どうしよう、周りが気になるっていう。緊張するみたいな。
# 仕事中の人とかも、ちょっと、ちょっと、足休めに、足をね、ちょっと座って休むために入る感じの雰囲気だから、もう、全然、一人、全然、一人いいですよね。しかも、コーヒーちょっとおいしいし、こととおる。
# 難しいですよね、注文。
# あれは、あります、あります。
# そうなんですね。あー。あとは、じゃあ、もう、一歩踏み出すだけって感じですね。
# でも、絶対、そういう時間は、もう、多分、そういう時間こそ、行ってる人たちは、もう、もう、それだけですよ。周りなんか気にしてない。
# ね、そう、ぜ、みんな同じ。
# もう、絶対、もう、そんな、リストアップしてるなら、あとは、クロワッサンね、チョコクロワッサンね。
# それ全員すごい良いと思います。それか、あとモーニングですね。
# ありがとうございました。
# 姿勢ね、保つのに筋肉、あの、背中とかお腹とかも使ってるって言いますしね。
# じゃあ、まあ、ちょっと怖い、手術はね、怖いことは怖いですけど、まあ、でも、あれですよ、きっと、ほんと、なんかが教えてくれたんだと思います。
# おい。
# そんな、心臓が痛、痛い、心臓、まあ、結果的には心臓じゃなかったにせよ、そんな救急車呼ぶぐらい痛いなんてね、ちょっと、ほんと、大変でしたよね、それは。
# 夜中の通販出た。
# こう、上がったり下がったりする。
# じゃあ、今日はどんなお話をしていきましょうか。
# あれ、いいですよ。あれ、まだ、もしも、持ってるんだったら。
# スクワットいいですけど、過酷じゃないですか。
# レモリオーションがね、動けばよかったんですけどね。
# 失礼しまーす。
# ダンスしてたり、
# すごーい、着々と。
# すごい、ちゃんと、計画が、計画性がすごいありますね。
# 体力的にも精神的にもね、厳しいですね。
# 今日は、えー、どんなお話をしていきましょうか。
# ホームヘルパーって名前じゃなくなったって聞いたことがあります。
# 言ったりしてますね。
# やってみるのもいいかも。あの、昔のでもいいと思うんですよね。その、カラオケで思い出せないじゃないですか。昔聞いてたけど、タイトルなんだっけ?みたいな。歌えたっけ?とかって。いうのも、YouTubeだったら、昔のやつもかなりのっ、のってるので。
# よろしくお願いします。
# カラオケってなんかいざ歌おうとすると曲名とか頭出てこないんですよね。いっぱい知ってるはずなのに、どれ、どれっていうのが。
# おかしい、なんか、探偵さんみたい。
# 私とかが、最近というか、まあ、コロナであんまり外に出なくなってからやるようになったのは、あの、私は皿洗いが好きなので、あの、皿洗いの時に曲をかけ、スマホで曲をかけながら、あの、足踏み?ステップじゃないですけど、もう、あの、ドスドスしてます。歩いながらドスドス。
# そう、そうなんですよね。やってる間中ずっと励ましてくれて、で、あの、いいですね、上手ですよ、うまいですよとか言ってくれる感じだったので、なんかそれを、で、しばらくやってからの、その、似たような曲を流しての、同じようなステップって感じだったので、なんかこう、頭の中で多分リフレインされてるんですよね、励ましが。
# そうですね、はい。うーん、なので、結構、それは、楽しくというか、結構、習慣化はしてるかなーっていうのもありますね。あとは、あの、結構、寝る前に、手足をこう、宙に上げて、寝転がって、こう、ブルブルブルブルとか。
# でも、それは、結構、効きますよ。あの、最初とか、結構、真面目にやると、あのー、結構、ぐったりくるというか。
# 軽い。
# やっぱ、あれですよね、外に強制的に、その、例えば会社に行くとかで、歩、行かないと、もう、ほんと歩かないですもんね。
# 楽ですもんね。
# 困るー。
# 止めちゃうわけにも。
# お子さんの興味があるものってなん、なんですかね、テーマパーク以外で、例えばその、歴史に興味がある子とかだったら、お城とかを巡ってみたりとかいうのもいいし。
# はいはいはいはい、ありますあります。
# 大人向けアスレチックみたいなところですよね。アスレチックやってるところ。
# ね、巨大迷路ね、とか、ありますもんね。
# そうそうそうそう。音楽、なんか、音が鳴ったりとか、そういう、ちょっと、なん、なん、あれはなんていうジャンルなのか、私もよくわからないんですけど、体感型の、なんか、そういうのが。
# 海外だとね、高くなっちゃいますもんね。海外に。
# You canとかね。
# ありますね、あの、あのー、水で、あと、最終的に水つけた筆でぼかすってやつですよね。
# 高い!もう、大人の、大人のですよね。色鉛筆とか言っちゃいけない。
# やっぱり、うん、起訴を。
# 絵を描くっていうのは、ど、どういう系の絵ですか?え、鉛筆、水彩画。
# なんか、絵ハガキとかになったりとかしてますよね、そういうやつで。
# カメラとかが、そのー、性能良くなってきたからこそ、こその、絵、絵ですよ、っていう、見たものを。
# それこそ、その、勉強されている内容で、最初はたぶんあんまり誰も見てくれなかったりとかするかもしれないですけど、ストーリーズとかあげて、その、韓国語練習中です、みたいな感じで、ちょこっと韓国語で発音して、しゃべって、友達が欲しいとかいうのをちょっとストーリーズであげたりとかしておくと、ちょっとその、興味のある人が声かけてくれる率は上がるかなって思います。
# いいですね。
# まあ、そうですね、そうですよね。
# こんにちは。
# ライズアップじゃなく。
# チェーン店的な感じで。おおー、すごい便利。
# そうですよね。ね、ううんうんうんうんうん。買い物ぐらいしか。
# それがこう、推奨されたのはコロナの時だけみたいな。
# お願いします。
# 予定が立っちゃってる。
# あるある。なんかね、ジャケット羽織ったら、なんかこう、あ、あれ、なんか、きついかも、みたいな、ぱ、ピツッて。
# うーん、人、重要だと思う、その、巻き込むのは、うーん。うふふふ。一人って気楽だけど、やっぱり、自分で自分、ね。
# なんか、それは、私にも言えることかなと思ったところで、お時間がよろしいようです。
# あれ、なんか、
# そうですよね。お休みの日に休まれちゃう。
# 高い、高い。ねえ。
# そう、あのー、ね、そう、な、ナチュラルな感じになってるのかどうかもわからないし。
# 高いんですかね?
# 折れる、折れるもん、やっぱ出川さんのあのぐらいの、メンタル持ってないと。
# じゃあ、今日はどんなお話をしていきましょうか。
# そうですよね。なんかね、仕事にするためにやるんだったらまだあれですけどね。うん、楽しんでやることがベースだってなると、なかなかお金も限度がある。
# あれかもしれないですよ、その、そのサークルとかで、ちょっと仲いい子と、一緒に、ちょっと、バイト行かない?とかって。あそこ、韓国の、韓国のママがやってる料理屋さんあるよ、とか。
# 結構募集してるところ多いと思うんですよね。焼肉屋さんとか。
# 趣味と実益を兼ねて。
# ありがとうございました。
# すごい。なんか、途中で飽きたりとか、なんか、もう、いやだーとか、投げ出しちゃったりとか、したくならないんですかね。
# すごい。
# 今日はどんなお話をしていきましょうか。
# そうなんですね。え、でも、スノーボードもできるってすごくないですか?え、運動神経いいですよね。あれ、できるって。
# なんで?運動は嫌いだけど、スノップは別枠みたいな。
# こんにちは。よろしくお願いします。
# じゃあ、え、新婚旅行もまだされてないというか、特に予定も立ってない感じなんですか?
# こんにちは。よろしくお願いします。
# ということで、えっと、そろそろお時間が来てしまいましたので、今日はこの辺で終わりにしたいと思います。はい。ありがとうございました。
# 優しい、いい人。
# 食事って感じじゃない。そっちじゃない。
# 金魚ね、いいですよね。実はいいですよね。
# そうそうそうそう。
# メダカとか多いですよね、あのー、好きで買ってる方って。
# 結構、道の駅とかで売られてたりするから、入手しやすいとも言う。ので。
# 魚類繋がりでいくと、きっとペットか、じゃなくても、カメとかいけるんじゃないですか?
# 確かに、磯臭い。そっか。それで、磯臭いからベランダにとかやると、ベランダ繋がりでご近所さんに迷惑がいったりすると。
# 家をね、ガリガリしたりとかしないので、ちょっと、もし、その、ね、うさぎがお好きだったら、結構、あの、ネズミ系もいけるんじゃないかなと。
# かわいいです。
# 危険、危険、危険、見失っちゃダメです、あのー、命に関わるから、あの子たちにとって。やばいです。
# 本当ですか?鳥類もいいですよ。ぶ、ぶんちゃんは。ぶんちゃんが可愛いですよ。夏来ますから、ちゃんと。
# ということで、今日はこの辺で終わりにしたいと思います。
# こんにちは。
# そこがね、そう、ちゃんと学ぼうとすると、あれですよね。あとは、あの、SNSで結構、結構、その、マーケティングを売ってる人っていうんですかね。の、本当かどうかわかんないですけど、その、ね、1ヶ月で年商いくらになりましたとかやって売ってる人がいるので、その辺の人たちの手法を、こう、研究してみるっていう。
# 今日は、どういったお話をしていきましょうか。
# 今日はどうも、いろいろ、夢のあるお話を伺えて楽しかったです。ありがとうございました。
# ありますよね、今、あのー、ラジオ配信みたいなやつですよね。
# 語学系で、えっと、語学に興味がある人に向けて、なんか、そのー、コツだとか、ってことを発信してるって感じですかね。
# 今日はどんなお話をしていきましょうか。
# すごいですね、多彩ですね。だって、あのー、クラリネットとか、その、笛と鍵盤って、なんか、もう、全然違うじゃないですか、指とかも。
# 昔からありましたよね。ゼルダで。
# こんにちは。
# アトラクションといえばあれですよね、沖縄だったら、結構、あのー、泊まった先の海とかでも、いろいろオプションの、ありますよね、バナナボートだとか。
# 新幹線も、そうですね、駅弁ですよね。やっぱり駅弁の思い出は作っとかないと。
# お城とか。
# 楽しめるかも。
# あと、そうですね。
# 男の子は特に好きですもんね。
# いいですよね、旅行。ご家族、普段もご家族とよく行かれてたんですか?その、コロナの前とかは。
# お昼とか、お昼、お昼に、そういう、なんていうんですかね、その地元の、例えば、牛が有名だったら、素敵なお店だとか、焼肉だとか、まあ、北海道とか、ドッジンギスカンとかあるし、大阪だとね、串焼きとかはもう、24時間いけるみたいな感じですしね。
# そうですね、いろいろなんか考えてるだけで楽しくなってくるんですが、結論はあまり出ないままですが、そろそろお時間がよろしいようです。はい、今日は、はい、ありがとうございました。それじゃあ、失礼します。
# お子さんってまだ小さくていらっしゃるんですか?
# うんじゅまんのレベルですよね。
# 結構、あれみたいですよ、その、本気で心配して言ってるんじゃなくて、その、あんまりその、お子さんがいない家庭とか、もう、お子さんが育ってる家庭とかが、うるさい!みたいなことを、なんか、伝えたいがために、でも、直接言いに行くと、けんが立つから、で、警察もあんまり動いて、そういうことでは動いてくれないから、じゃあ、自走に電話しようかな、みたいにやる人が結構、今、すごい多いみたいなので、
# ね、たとえ漏れてたとしても、一応、気にしてます、みたいな、このパフォーマンスで、ごめんなさい、みたいな、パフォーマンスで、締めるとかしてれば、まあ、ご記事は、たぶん、それで大丈夫じゃないかなと思いますね。
# かわいい格好とか女の子好きじゃないですか。だから、その、ちょっと、ね、あのー、リボンとか、スカートとかを、若干、その、動画とかに、食いついた動画に真似させて、フリフリさせて、その、お兄ちゃん、人に絡みに行かせないように。
# まだ、ね、ちょっと危ないですしね、4歳だとね、手元がね、ハーモンドとかあるところはちょっと怖いから。
# はい、それでは、ありがとうございます。失礼しまーす。
# お兄ちゃん頑張ってる。
# ドイツワイン、あと、うん、ドイツの白ワインとか、多分、甘、甘口なんですよね、確か。だから、結構、女の人が好きだったりするので。
# チーム見て走り。
# もともと、なんか、海外とかに住んでらっしゃったとか、そういうお仕事をされてたとかなんですか?
# あの、日本人からするとすごい謎のお菓子。
# どんな味なの?みたいな。
# なんか、それを、その、お仕事的にやっていくと、なんか、それを名目に人の輪が、ほんと、広がりそうですよね。日本に紹介します。
# だーすいー。
# 暮らすように。
# あー、いいですねー、いい。
# こんにちは。お願いします。今日はどんなお話をしていきましょうか。
# 上がらない。
# モチベーションになりますよね。会いに行く日が。
# あー、はいはいはいはいはい。そういうのとかで、その、遊びをかませてやってみるっていうのも、いいかもしれない。
# どう考えても、おもちゃ、おもちゃ、結構、どこの実家にもあるっていうね。
# きつい。きつい。
# それ、ちょっと、引っ張り出して。
# ね、あのー、女子力が高ければ、じゃあ、やっぱり、そこはヨガじゃないですか、自宅で、とかって言うんですけど、どうですか、ヨガ。
# こんにちは。
# ほんとですか?筋肉痛とかならなかったんですか?最初の頃は。
# それ、すごいありますよね。アルバイトでも、あのー、一見、そのー、短時間のバイトなんだけど、間に1.5時間の昼休みとか入ってた時があって、
# つらい。
# ありますね。バイト、結構、その、移動時間結構重要ですよね。
# 困っちゃいますね。
# いやー、でも、え、でも、それは初めて聞いた。すごいお得、そんな。
# そうですけど。
# なるほど。
# でも、2リットルのペットボトル、何本も入ってるやつって、ものすごい重くないですか?

# %%
texts = [
    "最近芸人さんとかでそういう方多いですもんね。",
    "コントローラーでこう、手でやるよりも、マウスの方がピタッとくる感じなんですかね。",
    "実は全然、顔を映さなければ、全然別人だったり、みたいな。"
]

# %% [markdown]
# ## Synthesis

# %%
outputs, rtfs = [], []
rtfs_w = []
for i, text in enumerate(tqdm(texts)):
    output = synthesise(text) #, torch.tensor([15], device=device, dtype=torch.long).unsqueeze(0))
    print(output['decoder_outputs_mel'].shape)
    output['waveform'] = to_waveform(output['mel'], vocoder)

    # Compute Real Time Factor (RTF) with HiFi-GAN
    t = (dt.datetime.now() - output['start_t']).total_seconds()
    rtf_w = t * 16000 / (output['waveform'].shape[-1])
    dur = output['waveform'].shape[-1] / 16000

    ## Pretty print
    """
    print(f"{'*' * 53}")
    print(f"Input text - {i}")
    print(f"{'-' * 53}")
    print(output['x_orig'])
    print(f"{'*' * 53}")
    print(f"Phonetised text - {i}")
    print(f"{'-' * 53}")
    print(output['x_phones'])
    print(f"{'*' * 53}")
    print(f"RTF:\t\t{output['rtf']*16000/22050:.6f}")
    print(f"RTF Waveform:\t{rtf_w:.6f}")
    print(f"Audio duration:\t{dur:.6f}")
    """
    rtfs.append(output['rtf'])#*16000/22050)
    rtfs_w.append(rtf_w)
    outputs.append(output)

    ## Display the synthesised waveform
    ipd.display(ipd.Audio(output['waveform'], rate=16000))

    ## Save the generated waveform
    #save_to_folder(f"test_base_500_{i}", output, OUTPUT_FOLDER)

    ## face
    #save_to_movement_csv(f"test_base_500_{i}", output, "movement_output")

print(f"Number of ODE steps: {n_timesteps}")
print(f"Mean RTF:\t\t\t\t{np.mean(rtfs):.6f} ± {np.std(rtfs):.6f}")
print(f"Mean RTF Waveform (incl. vocoder):\t{np.mean(rtfs_w):.6f} ± {np.std(rtfs_w):.6f}")
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# INFO:speechbrain.utils.fetching:Fetch hyperparams.yaml: Fetching from HuggingFace Hub 'speechbrain/tts-hifigan-libritts-16kHz' if not cached
# torch.Size([1, 80, 166])
# INFO:speechbrain.utils.fetching:Fetch custom.py: Fetching from HuggingFace Hub 'speechbrain/tts-hifigan-libritts-16kHz' if not cached
# INFO:speechbrain.utils.fetching:Fetch generator.ckpt: Fetching from HuggingFace Hub 'speechbrain/tts-hifigan-libritts-16kHz' if not cached
# INFO:speechbrain.utils.parameter_transfer:Loading pretrained files for: generator
# /home/ayrton/anaconda3/envs/match-ttsg-wsl/lib/python3.10/site-packages/speechbrain/utils/checkpoints.py:200: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(path, map_location=device)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# INFO:speechbrain.utils.fetching:Fetch hyperparams.yaml: Fetching from HuggingFace Hub 'speechbrain/tts-hifigan-libritts-16kHz' if not cached
# INFO:speechbrain.utils.fetching:Fetch custom.py: Fetching from HuggingFace Hub 'speechbrain/tts-hifigan-libritts-16kHz' if not cached
# torch.Size([1, 80, 314])
# INFO:speechbrain.utils.fetching:Fetch generator.ckpt: Fetching from HuggingFace Hub 'speechbrain/tts-hifigan-libritts-16kHz' if not cached
# INFO:speechbrain.utils.parameter_transfer:Loading pretrained files for: generator
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# INFO:speechbrain.utils.fetching:Fetch hyperparams.yaml: Fetching from HuggingFace Hub 'speechbrain/tts-hifigan-libritts-16kHz' if not cached
# INFO:speechbrain.utils.fetching:Fetch custom.py: Fetching from HuggingFace Hub 'speechbrain/tts-hifigan-libritts-16kHz' if not cached
# torch.Size([1, 80, 277])
# INFO:speechbrain.utils.fetching:Fetch generator.ckpt: Fetching from HuggingFace Hub 'speechbrain/tts-hifigan-libritts-16kHz' if not cached
# INFO:speechbrain.utils.parameter_transfer:Loading pretrained files for: generator
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Number of ODE steps: 500
# Mean RTF:				1.262265 ± 0.402515
# Mean RTF Waveform (incl. vocoder):	1.555122 ± 0.492690

# %%
print(f"Number of ODE steps: {n_timesteps}")
print(f"Mean RTF:\t\t\t\t{np.mean(rtfs):.6f} ± {np.std(rtfs):.6f}")
print(f"Mean RTF Waveform (incl. vocoder):\t{np.mean(rtfs_w):.6f} ± {np.std(rtfs_w):.6f}")
# Out:
# Number of ODE steps: 500
# Mean RTF:				1.262265 ± 0.402515
# Mean RTF Waveform (incl. vocoder):	1.555122 ± 0.492690
